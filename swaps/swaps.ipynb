# %% [markdown]
# ### Swaps:
# Swaps involve the exchange of cash flows or payments based on specified conditions.
# - Common types include interest rate swaps, currency swaps, and credit default swaps.
# - Swaps are often used for managing interest rate risk, currency exposure, or credit risk.
#
# URL: https://www.youtube.com/watch?v=MUpbVa81T3o
#
# ![image.png](attachment:a336d900-b07d-4d04-a05c-f759d2744748.png)
