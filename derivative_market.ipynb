# %% [markdown]
# ![image.png](attachment:574a0b5a-ddd2-45d0-b7d9-4e3478adbb12.png)

# %% [markdown]
# <style>
# .highlight {
#     background-color: yellow !important;
#     padding: 5px !important;
# }
# </style>

# %% [markdown]
# <style>
# .highlight {
#     background-color: yellow !important;
#     padding: 5px !important;
# }
# </style>

# %% [markdown]
# <a href="https://www.youtube.com/watch?v=K9rWHQEVN44" style="color: blue; text-decoration: underline;">Watch this video on Derivatives</a>
